# %% [markdown]
# # 🚦 CrashSense: Code vs Markdown Demo
#
# ## Purpose
# This notebook demonstrates the difference between Code cells and Markdown cells.

# %% [markdown]
# ## Code Example 1
# This code cell will print a message.

# %%
print("FraudGuard is working!")
# Out:
# CrashSense is working!

# %% [markdown]
# ### Explanation
# This Code cell runs Python code and prints output.
# Code cells are used for execution.

# %%
a = 5
b = 10
print("Sum:", a + b)
# Out:
# Sum: 15

# %% [markdown]
# ### Explanation
# This Code cell performs addition.
#
# Markdown cells are used for:
# - Explanation
# - Documentation
# - Readability
